# %%
# 라이브러리 임포트
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from scipy.cluster.hierarchy import linkage, dendrogram

from sklearn.cluster import AgglomerativeClustering
from sklearn import metrics

# %%
# 합성 데이터 데이터 파일(syn_data.xlsx) 불러오기
var_names = ['x1', 'x2']
x_df = pd."""판다스 함수"""("""파일 경로 및 이름""", header=None, names=var_names)
x_df.head()
# Out:
#        x1      x2
# 0  664159  550946
# 1  665845  557965
# 2  597173  575538
# 3  618600  551446
# 4  635690  608046

# %%
# 데이터를 numpy array 형태로 추출
x =

# %%
# 덴드로그램 작성을 위한 linkage matrix Z 계산
Z =

# %%
# 덴드로그램 작성 함수
def plot_dendrogram(link_mat, n_clusters, mode=None, truncate_p=100):
    plt.figure()
    plt.title('Hierarchical Clustering (Ward) Dendrogram')
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(
        link_mat,
        color_threshold = Z[1-n_clusters, 2],
        truncate_mode = mode,
        p = truncate_p
    )
    plt.show()

# %%
# 덴드로그램 작성 (마지막 20 단계만 작성, 군집 개수는 무관)
""" 위 함수 사용 """

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 덴드로그램을 통해 예상한 군집 개수 후보 리스트
num_clusters_set = np.arange(2, 20)
num_clusters_set

# %%
""" 각 군집 개수 후보에 대해 군집화 학습 및 결과 plotting """
for num_clusters in num_clusters_set:
    
    print('--------------------------------')
    print('The number of clusters:', num_clusters)
    
    ward = 
    
    unique_labels = 
    
    for label_i in unique_labels:
        cluster_member_mask = 
        
        x_cluster_i = 
        
        plt.scatter("""작성""")
    
    plt.title('hierarchical clustering (ward) result')
    plt.xlabel('x1')
    plt.ylabel('x2')
    plt.legend()
    plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
