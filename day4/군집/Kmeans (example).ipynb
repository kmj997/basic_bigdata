# %%
# 라이브러리 임포트
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn import metrics
from sklearn.cluster import KMeans  # K-means 임포트
from sklearn.preprocessing import StandardScaler

# %%
# 군집 알고리즘 연습을 위한 예제 데이터 생성
x = np.c_[[4, 20, 3, 19, 17, 8, 19, 18],
         [15, 13, 13, 4, 17, 11, 12, 6]]
x_df = pd.DataFrame(x, columns=['experience', 'violation'])
x_df
# Out:
#    experience  violation
# 0           4         15
# 1          20         13
# 2           3         13
# 3          19          4
# 4          17         17
# 5           8         11
# 6          19         12
# 7          18          6

# %%
# 파라미터 설정
num_clusters = 3  # 군집 개수

# %%
# K-means 군집화 알고리즘 실행
kmeans = KMeans(n_clusters=num_clusters, init='k-means++')
kmeans.fit(x)
kmeans.labels_
# Out:
# array([1, 2, 1, 0, 2, 1, 2, 0])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 군집화 결과 plotting
unique_labels = np.unique(kmeans.labels_)  # 군집 종류

centroids = []
for i in unique_labels:  # 각 군집에 대해
    cluster_instance_mask = (kmeans.labels_ == i)
    
    x_cluster_i = x[cluster_instance_mask, :]  # 해당 군집에 해당하는 인스턴스
    centroids.append(np.mean(x_cluster_i, axis=0))
    
    plt.scatter(x_cluster_i[:, 0], x_cluster_i[:, 1], label='cluster ' + str(i))  # 1번째, 2번째 변수를 이용해 plotting

plt.title('example K-means result')
plt.xlabel('experience')
plt.ylabel('violation')
plt.legend()
plt.show()

# %%
""" Practice 1: 아래 내용을 완성하세요 (10분) """

# %%
# 먼 객체들로 초기 객체 선정한 모형의 결과값(label) 저장
kmeans_farthest_labels =

# %%
# 랜덤 초기화 방법으로 K-means 군집화 알고리즘 실행
kmeans = 

# 랜덤 초기화 모형의 결과값(label) 저장
kmeans_random_labels =

# %%
# 랜덤 초기화 군집화 결과 plotting
unique_labels = np.unique(kmeans.labels_)  # 군집 종류

for i in unique_labels:  # 각 군집에 대해
    cluster_member_mask = (kmeans.labels_ == i)
    
    x_cluster_i = x[cluster_member_mask, :]  # 해당 군집에 해당하는 인스턴스
    
    plt.scatter(x_cluster_i[:, 0], x_cluster_i[:, 1], label='cluster ' + str(i))  # 1번째, 2번째 변수를 이용해 plotting

plt.title('example K-means result')
plt.xlabel('experience')
plt.ylabel('violation')
plt.legend()
plt.show()

# %%
# 초기 중심객체로 사용할 1, 2, 3번째 인스턴스 추출
init_cents = 
# 선정된 초기 중심객체를 이용해 K-means 군집화 알고리즘 실행
kmeans = 

# 결과값 저장
kmeans_manual_labels =

# %%
# 특정 객체 초기화 군집화 결과 plotting
unique_labels = np.unique(kmeans.labels_)  # 군집 종류

for i in unique_labels:  # 각 군집에 대해
    cluster_member_mask = (kmeans.labels_ == i)
    
    x_cluster_i = x[cluster_member_mask, :]  # 해당 군집에 해당하는 인스턴스
    
    plt.scatter(x_cluster_i[:, 0], x_cluster_i[:, 1], label='cluster ' + str(i))  # 1번째, 2번째 변수를 이용해 plotting

plt.title('example K-means result')
plt.xlabel('experience')
plt.ylabel('violation')
plt.legend()
plt.show()

# %%
""" Practice 2: 아래 내용을 완성하세요 (10분) """

# %%
# 군집 개수 2개일 경우 (without standardization)
num_clusters = 

kmeans = 

num_clusters =

# %%
# 군집 개수 2개일 경우 (with standardization)
scaler = StandardScaler()
x_std = 

num_clusters =
# Out:
# c:\users\taekho\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# c:\users\taekho\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int32 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
